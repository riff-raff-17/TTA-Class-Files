# %%
var = 10
print(var)
# Out:
# 10

# %%
fruits = ["apple", "banana", "cherry"]

# Accessing
# Lists start at 0!
print("Fruit number 1 is", fruits[0])
# Out:
# Fruit number 1 is apple

# %%
fruits.append("dragonfruit")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'dragonfruit']

# %%
fruits.insert(0, "phone")
print(fruits)
# Out:
# ['phone', 'apple', 'banana', 'cherry', 'dragonfruit']

# %%
fruits.remove("phone")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'dragonfruit']
