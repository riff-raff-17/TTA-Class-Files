# %%
pip install sounddevice numpy openai-whisper soundfile

# %%
import whisper
import sounddevice as sd
import soundfile as sf

# 5 models: tiny/base/small/medium/large
model = whisper.load_model("base")

sample_rate = 8000
sec = 3

audio = sd.rec(int(sec * sample_rate), samplerate=sample_rate, channels=1, dtype="float32")
print("Listening!")
sd.wait()
sf.write("temp.wav", audio, sample_rate)

result = model.transcribe("temp.wav")
phrase = result["text"].strip() # strip() removes whitespace
print(f"You said: {phrase}")

command, *rest = phrase.split()
action = " ".join(rest)

if command == "Say":
    print(f"Saying \"{action}\"")
if command == "Go":
    print(f"Going \"{action}\"")
if command == "Do":
    print(f"Doing \"{action}\"")
# Out:
# Listening!
# /Users/rafalr/Desktop/GitHub/TTA-Class-Files/2026 Term 2/L4212T1 - Sat/.venv/lib/python3.13/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# You said: Hello Drew, how are you doing?
