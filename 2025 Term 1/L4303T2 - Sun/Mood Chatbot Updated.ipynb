# %%
import random
import webbrowser
from tkinter import Tk, Label, Text, Button, StringVar, Listbox, END
from textblob import TextBlob

# Sample playlists for different moods
playlists = {
    "positive": {
        "Happy - Pharrell Williams": 'https://www.youtube.com/watch?v=ZbZSe6N_BXs',
        "Can't Stop the Feeling! - Justin Timberlake": 'https://www.youtube.com/watch?v=ru0K8uYEZWw',
        "Uptown Funk - Mark Ronson ft. Bruno Mars": 'https://www.youtube.com/watch?v=OPf0YbXqDm0',
        "Good Vibes - Chris Janson": 'https://www.youtube.com/watch?v=hNRJjDm2sQE'
    },
    "neutral": {
        "Let It Be - The Beatles": 'https://www.youtube.com/watch?v=CGj85pVzRJs',
        "Boulevard of Broken Dreams - Green Day": 'https://www.youtube.com/watch?v=Soa3gO7tL-c',
        "Yellow - Coldplay": 'https://www.youtube.com/watch?v=yKNxeF4KMsY',
        "Wake Me Up - Avicii": 'https://www.youtube.com/watch?v=IcrbM1l_BoI',
        "Shape of You - Ed Sheeran": 'https://www.youtube.com/watch?v=JGwWNGJdvx8'
    },
    "negative": {
        "Someone Like You - Adele": 'https://www.youtube.com/watch?v=hLQl3WQQoQ0',
        "Fix You - Coldplay": 'https://www.youtube.com/watch?v=k4V3Mo61fJM',
        "Hurt - Johnny Cash": 'https://www.youtube.com/watch?v=8AHCfZTRGiI',
        "Mad World - Gary Jules": 'https://www.youtube.com/watch?v=etSbOs3aUqI',
        "Never Gonna Give You Up - Rick Astley": "https://www.youtube.com/watch?v=dQw4w9WgXcQ"
    }
}

responses = {
    "positive": "Wow! You seem like you're having a good day! Here's some songs for you",
    "neutral": "Interesting. You seem calm or thoughtful. Here's some songs for you.",
    "negative": "I'm here for you. Here's some songs to cheer you up."
}

def analyze_sentiment(text):
    """Analyze sentiment and return mood (positive, neutral, or negative)."""
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    if polarity > 0.2: # change these to adjust chatbot sensitivity
        return "positive"
    elif polarity < -0.2:
        return "negative"
    else:
        return "neutral"

def generate_playlist(mood):
    """Generate a playlist based on the mood."""
    return random.sample(list(playlists[mood].items()), k=len(playlists[mood]))

def get_playlist():
    user_text = input_text.get("1.0", END).strip()
    if not user_text:
        result_var.set("Please enter some text!")
        return
    
    mood = analyze_sentiment(user_text)
    playlist = generate_playlist(mood)
    
    result_var.set(f"Detected mood: {mood.capitalize()}")
    song_list.delete(0, END)
    for song, url in playlist:
        song_list.insert(END, song)
        song_links[song] = url

def open_song(event): 
    """Open the song in YouTube"""
    selected_song = song_list.get(song_list.curselection())
    url = song_links.get(selected_song)
    if url:
        webbrowser.open(url)

#___________________________________________________________

# Create the main window
root = Tk()
root.title("Mood-Based Playlist Generator")

# Input Text
Label(root, text="Enter your text:").pack(pady=5)
input_text = Text(root, height=5, width=40)
input_text.pack(pady=5)

# Generate Button
Button(root, text="Generate Playlist", command=get_playlist).pack(pady=10)

# Result Label
result_var = StringVar()
result_label = Label(root, textvariable=result_var, wraplength=300, justify="left")
result_label.pack(pady=10)

# Song Listbox 
song_list = Listbox(root, height = 10, width = 50)
song_list.pack(pady=5)
song_list.bind("<<ListboxSelect>>", open_song)

# Dictionary to store song links
song_links = {}

# Run the GUI loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 93
#      90 result_label.pack(pady=10)
#      92 # Song Listbox
# ---> 93 song_list = Listbox(root, height = 10, width = 50)
#      94 song_list.pack(pady=5)
#      95 song_list.bind("<<ListboxSelect>>", open_song)
#
# NameError: name 'Listbox' is not defined

# %%
import random
import webbrowser
from tkinter import Tk, Label, Text, Button, StringVar, Listbox, Entry, END, OptionMenu
from textblob import TextBlob

# Sample playlists for different moods
playlists = {
    "positive": {
        "Happy - Pharrell Williams": 'https://www.youtube.com/watch?v=ZbZSe6N_BXs',
        "Can't Stop the Feeling! - Justin Timberlake": 'https://www.youtube.com/watch?v=ru0K8uYEZWw',
        "Uptown Funk - Mark Ronson ft. Bruno Mars": 'https://www.youtube.com/watch?v=OPf0YbXqDm0',
        "Good Vibes - Chris Janson": 'https://www.youtube.com/watch?v=hNRJjDm2sQE'
    },
    "neutral": {
        "Let It Be - The Beatles": 'https://www.youtube.com/watch?v=CGj85pVzRJs',
        "Boulevard of Broken Dreams - Green Day": 'https://www.youtube.com/watch?v=Soa3gO7tL-c',
        "Yellow - Coldplay": 'https://www.youtube.com/watch?v=yKNxeF4KMsY',
        "Wake Me Up - Avicii": 'https://www.youtube.com/watch?v=IcrbM1l_BoI',
        "Shape of You - Ed Sheeran": 'https://www.youtube.com/watch?v=JGwWNGJdvx8'
    },
    "negative": {
        "Someone Like You - Adele": 'https://www.youtube.com/watch?v=hLQl3WQQoQ0',
        "Fix You - Coldplay": 'https://www.youtube.com/watch?v=k4V3Mo61fJM',
        "Hurt - Johnny Cash": 'https://www.youtube.com/watch?v=8AHCfZTRGiI',
        "Mad World - Gary Jules": 'https://www.youtube.com/watch?v=etSbOs3aUqI',
        "Never Gonna Give You Up - Rick Astley": "https://www.youtube.com/watch?v=dQw4w9WgXcQ"
    }
}

responses = {
    "positive": "Wow! You seem like you're having a good day! Here's some songs for you",
    "neutral": "Interesting. You seem calm or thoughtful. Here's some songs for you.",
    "negative": "I'm here for you. Here's some songs to cheer you up."
}

def analyze_sentiment(text):
    """Analyze sentiment and return mood (positive, neutral, or negative)."""
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    if polarity > 0.2: # change these to adjust chatbot sensitivity
        return "positive"
    elif polarity < -0.2:
        return "negative"
    else:
        return "neutral"

def generate_playlist(mood):
    """Generate a playlist based on the mood."""
    return random.sample(list(playlists[mood].items()), k=len(playlists[mood]))

def get_playlist():
    user_text = input_text.get("1.0", END).strip()
    if not user_text:
        result_var.set("Please enter some text!")
        return
    
    mood = analyze_sentiment(user_text)
    playlist = generate_playlist(mood)
    
    result_var.set(f"Detected mood: {mood.capitalize()}")
    song_list.delete(0, END)
    for song, url in playlist:
        song_list.insert(END, song)
        song_links[song] = url

def open_song(event): 
    """Open the song in YouTube"""
    selected_song = song_list.get(song_list.curselection())
    url = song_links.get(selected_song)
    if url:
        webbrowser.open(url)

def add_song():
    """Add a new song to the playlist."""
    song = song_entry.get().strip()
    url = url_entry.get().strip()
    mood = mood_var.get()
    
    if not song or not url or mood not in playlists:
        result_var.set("Please enter a valid song name, URL, and select a mood.")
        return
    
    playlists[mood][song] = url
    result_var.set(f"Added '{song}' to {mood} playlist!")

#___________________________________________________________

# Create the main window
root = Tk()
root.title("Mood-Based Playlist Generator")

# Input Text
Label(root, text="Enter your text:").pack(pady=5)
input_text = Text(root, height=5, width=40)
input_text.pack(pady=5)

# Generate Button
Button(root, text="Generate Playlist", command=get_playlist).pack(pady=10)

# Result Label
result_var = StringVar()
result_label = Label(root, textvariable=result_var, wraplength=300, justify="left")
result_label.pack(pady=10)

# Song Listbox 
song_list = Listbox(root, height = 10, width = 50)
song_list.pack(pady=5)
song_list.bind("<<ListboxSelect>>", open_song)

# Dictionary to store song links
song_links = {}

# Add Song Section
Label(root, text="Add a song:").pack(pady=5)
song_entry = Entry(root, width=40)
song_entry.pack(pady=2)
Label(root, text="YouTube URL:").pack(pady=2)
url_entry = Entry(root, width=40)
url_entry.pack(pady=2)
Label(root, text="Select Mood:").pack(pady=2)
mood_var = StringVar(root)
mood_var.set("positive")  # Default mood
mood_menu = OptionMenu(root, mood_var, "positive", "neutral", "negative")
mood_menu.pack(pady=2)
Button(root, text="Add Song", command=add_song).pack(pady=5)

# Run the GUI loop
root.mainloop()
